# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('music_genre_cleaned.csv')
df
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 0              31       0.01270         0.622       218293    high
# 1              28       0.00306         0.620       215613    high
# 2              34       0.02540         0.774       166875  medium
# 3              32       0.00465         0.638       222369  medium
# 4              46       0.02890         0.572       214408    high
# ...           ...           ...           ...          ...     ...
# 40555          56       0.13300         0.849       237667  medium
# 40556          72       0.15700         0.709       251860     low
# 40557          51       0.00597         0.693       189483    high
# 40558          65       0.08310         0.782       262773     low
# 40559          67       0.10200         0.862       267267  medium
#
#        instrumentalness  liveness  loudness  speechiness  tempo  valence  \
# 0              0.950000     0.124    -7.043       0.0300    115    0.531
# 1              0.011800     0.534    -4.617       0.0345    128    0.333
# 2              0.002530     0.157    -4.498       0.2390    128    0.270
# 3              0.909000     0.157    -6.266       0.0413    145    0.323
# 4              0.000008     0.106    -4.294       0.3510    150    0.230
# ...                 ...       ...       ...          ...    ...      ...
# 40555          0.000008     0.296    -7.195       0.0516    100    0.629
# 40556          0.000000     0.109    -9.814       0.0550    122    0.113
# 40557          0.000000     0.143    -5.443       0.1460    131    0.395
# 40558          0.000000     0.106    -5.016       0.0441     76    0.354
# 40559          0.000000     0.272   -13.652       0.1010     99    0.765
#
#       music_genre
# 0      Electronic
# 1      Electronic
# 2      Electronic
# 3      Electronic
# 4      Electronic
# ...           ...
# 40555     Hip-Hop
# 40556     Hip-Hop
# 40557     Hip-Hop
# 40558     Hip-Hop
# 40559     Hip-Hop
#
# [40560 rows x 12 columns]

# %% [markdown]
# # Kardinalumas

# %%
df.nunique()
# Out:
# popularity             98
# acousticness         4067
# danceability         1054
# duration_ms         24279
# energy                  3
# instrumentalness     4974
# liveness             1623
# loudness            15725
# speechiness          1320
# tempo                 182
# valence              1599
# music_genre            10
# dtype: int64

# %%
max(df.duration_ms)
# Out:
# 4497994

# %%
df.music_genre.describe()
# Out:
# count     40560
# unique       10
# top        Rock
# freq       4099
# Name: music_genre, dtype: object

# %%
df.energy.describe()
# Out:
# count     40560
# unique        3
# top        high
# freq      13929
# Name: energy, dtype: object

# %%
plt.hist(df.popularity)
# Out:
# (array([ 832., 1551., 4397., 8708., 8658., 9694., 5164., 1365.,  175.,
#           16.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.acousticness)
# Out:
# (array([17941.,  4597.,  2916.,  2277.,  1849.,  1574.,  1462.,  1495.,
#          1711.,  4738.]),
#  array([0.    , 0.0996, 0.1992, 0.2988, 0.3984, 0.498 , 0.5976, 0.6972,
#         0.7968, 0.8964, 0.996 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.danceability)
# Out:
# (array([ 723., 1521., 2619., 4521., 6740., 8336., 7535., 5194., 2698.,
#          673.]),
#  array([0.0596 , 0.15224, 0.24488, 0.33752, 0.43016, 0.5228 , 0.61544,
#         0.70808, 0.80072, 0.89336, 0.986  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.duration_ms)
# Out:
# (array([3.9249e+04, 1.1940e+03, 9.3000e+01, 1.6000e+01, 3.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([  15509. ,  463757.5,  912006. , 1360254.5, 1808503. , 2256751.5,
#         2705000. , 3153248.5, 3601497. , 4049745.5, 4497994. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.energy)
# Out:
# (array([13929.,     0.,     0.,     0.,     0., 13687.,     0.,     0.,
#             0., 12944.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.instrumentalness)
# Out:
# (array([29718.,  1156.,   679.,   598.,   586.,   615.,   768.,  1135.,
#          2717.,  2588.]),
#  array([0.    , 0.0996, 0.1992, 0.2988, 0.3984, 0.498 , 0.5976, 0.6972,
#         0.7968, 0.8964, 0.996 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.liveness)
# Out:
# (array([14640., 13875.,  4698.,  4039.,   993.,   632.,   720.,   411.,
#           239.,   313.]),
#  array([0.00967 , 0.108703, 0.207736, 0.306769, 0.405802, 0.504835,
#         0.603868, 0.702901, 0.801934, 0.900967, 1.      ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.loudness)
# Out:
# (array([1.6000e+01, 7.4000e+01, 2.7700e+02, 7.0800e+02, 1.3770e+03,
#         1.9780e+03, 4.6050e+03, 1.5158e+04, 1.6099e+04, 2.6800e+02]),
#  array([-47.046, -41.967, -36.888, -31.809, -26.73 , -21.651, -16.572,
#         -11.493,  -6.414,  -1.335,   3.744]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.speechiness)
# Out:
# (array([3.1617e+04, 3.7110e+03, 2.5900e+03, 1.6590e+03, 6.5600e+02,
#         2.1000e+02, 5.3000e+01, 2.8000e+01, 1.6000e+01, 2.0000e+01]),
#  array([0.0223 , 0.11427, 0.20624, 0.29821, 0.39018, 0.48215, 0.57412,
#         0.66609, 0.75806, 0.85003, 0.942  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.tempo)
# Out:
# (array([  46.,  943., 6365., 8763., 7753., 8320., 4562., 2913.,  746.,
#          149.]),
#  array([ 34. ,  52.6,  71.2,  89.8, 108.4, 127. , 145.6, 164.2, 182.8,
#         201.4, 220. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.valence)
# Out:
# (array([3232., 4119., 4745., 5494., 5092., 5285., 4605., 3636., 2686.,
#         1666.]),
#  array([0.    , 0.0992, 0.1984, 0.2976, 0.3968, 0.496 , 0.5952, 0.6944,
#         0.7936, 0.8928, 0.992 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.music_genre)
# Out:
# (array([4032., 4064., 4064., 4051., 4049., 4042., 4046., 4099., 4036.,
#         4077.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)
